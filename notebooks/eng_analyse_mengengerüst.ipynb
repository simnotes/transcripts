# %%
import csv
import pandas as pd

# %%
test = pd.read_csv('../corpora/eng/cv-valid-test.csv', 
        parse_dates=False,
        engine="python",
        encoding="utf-8",
        error_bad_lines=False,
        quotechar='"',
        quoting=csv.QUOTE_NONE,)
test["text"].value_counts().to_frame().reset_index().describe()
# Out:
#               text
# count  2362.000000
# mean      1.691363
# std       1.267989
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max      12.000000

# %%
train = pd.read_csv('../corpora/eng/cv-valid-train.csv', 
        parse_dates=False,
        engine="python",
        encoding="utf-8",
        error_bad_lines=False,
        quotechar='"',
        quoting=csv.QUOTE_NONE,)
train["text"].value_counts().to_frame().reset_index().describe()
# Out:
#               text
# count  6994.000000
# mean     27.991993
# std      38.371750
# min       1.000000
# 25%       9.000000
# 50%      16.000000
# 75%      29.000000
# max     265.000000

# %%
dev = pd.read_csv('../corpora/eng/cv-valid-dev.csv', 
        parse_dates=False,
        engine="python",
        encoding="utf-8",
        error_bad_lines=False,
        quotechar='"',
        quoting=csv.QUOTE_NONE,)
dev["text"].value_counts().to_frame().reset_index().describe()
# Out:
#               text
# count  2410.000000
# mean      1.691286
# std       1.237694
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max      12.000000

# %%
train.loc[ lambda df: (df.up_votes + df.down_votes > 1) & (df.up_votes > df.down_votes), : ]
# Out:
#                                 filename  \
# 4       cv-valid-train/sample-000004.mp3
# 6       cv-valid-train/sample-000006.mp3
# 7       cv-valid-train/sample-000007.mp3
# 8       cv-valid-train/sample-000008.mp3
# 11      cv-valid-train/sample-000011.mp3
# 12      cv-valid-train/sample-000012.mp3
# 15      cv-valid-train/sample-000015.mp3
# 17      cv-valid-train/sample-000017.mp3
# 20      cv-valid-train/sample-000020.mp3
# 21      cv-valid-train/sample-000021.mp3
# 22      cv-valid-train/sample-000022.mp3
# 23      cv-valid-train/sample-000023.mp3
# 24      cv-valid-train/sample-000024.mp3
# 26      cv-valid-train/sample-000026.mp3
# 27      cv-valid-train/sample-000027.mp3
# 30      cv-valid-train/sample-000030.mp3
# 31      cv-valid-train/sample-000031.mp3
# 32      cv-valid-train/sample-000032.mp3
# 36      cv-valid-train/sample-000036.mp3
# 37      cv-valid-train/sample-000037.mp3
# 38      cv-valid-train/sample-000038.mp3
# 39      cv-valid-train/sample-000039.mp3
# ...
