# %%
import xml.etree.ElementTree as et
import pandas as pd
from sox import Transformer
from os import path, walk

# disable truncated columns
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 1000)

# use full siza of display / can be enabled on bigger screens
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
def parse_sentence(sentence_node):
    sentence = ""
    start = 99999999999999
    end = 0
    
    for t in sentence_node.iterfind("t"):
        sentence += t.text + " "
        for n in t.iterfind("n"):
            if n.get("start") != None and start > int(n.get("start")):
                start = int(n.get("start"))
            if n.get("end") != None and end < int(n.get("end")):
                end = int(n.get("end"))

    return {"sentence": [sentence], "start": [start], "end": [end], "length": [end - start]}

def parse_article_header_description(xroot):
    columns = ["sentence", "start", "end", "length"]
    df = pd.DataFrame(columns=columns)
    
    for d in xroot.iterfind("d"):
        for p in d.iterfind("p"):
            for s in p.iterfind("s"):
                sentence_dict = parse_sentence(s)
                df = pd.concat([df, pd.DataFrame(sentence_dict)])
                
    return df
                
def parse_sections(xroot):
    columns = ["sentence", "start", "end", "length"]
    df = pd.DataFrame(columns=columns)
    
    for d in xroot.iterfind("d"):
        for section in d.iterfind("section"):
            for sectioncontent in section.iterfind("sectioncontent"):
                for p in sectioncontent.iterfind("p"):
                    for s in p.iterfind("s"):
                        sentence_dict = parse_sentence(s)
                        df = pd.concat([df, pd.DataFrame(sentence_dict)])
                            
    return df

def _convert_wav(path_prefix, filepath, sentence):
    _maybe_convert_wav(mp3_path, wav_path)
    frames = int(subprocess.check_output(['soxi', '-s', wav_path], stderr=subprocess.STDOUT))
    wav_file_size = path.getsize(wav_path)

    status = "no_status"

    if int(frames/SAMPLE_RATE*1000/10/2) < len(str(sentence)):
        # Excluding samples that are too short to fit the transcript
        status = "too_short"
    elif frames/SAMPLE_RATE > MAX_SECS:
        # Excluding very long samples to keep a reasonable batch-size
        status = "too_long"
    else:
        status = "ok"

    return pd.Series([wav_path, wav_file_size, status])

# %%
def parse_file(base_folder):
    filepath = path.join(base_folder, "aligned.swc")
    
    xtree = et.parse(filepath)
    xroot = xtree.getroot()
    df_header = parse_article_header_description(xroot)
    df_sections = parse_sections(xroot)
    df = pd.concat([df_header, df_sections])
    df["base_folder"] = base_folder
    df["status"] = "no_status"
    
    return df

def create_worklist(base_folder_path):
    df_complete_columns = ["sentence", "start", "end", "length", "base_folder", "status"]
    df_complete = pd.DataFrame(columns=df_complete_columns)
    
    for root, dirnames, filenames in walk(base_folder_path):
        for dirname in dirnames:
            file_path = path.join(base_folder_path, dirname)
            if path.exists(path.join(file_path, "aligned.swc")):
                df_complete = pd.concat([df_complete, parse_file(file_path)])
        break
        
    return df_complete.reset_index().drop("index", axis=1)

basepath = "../corpora/wiki/german/"

dff = create_worklist(basepath)
dff
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            sentence  \
# 0      Die Resolution 1860 des UN-Sicherheitsrates ist eine völkerrechtlich bindende UN-Resolution , die der Sicherheitsrat der Vereinten Nationen am 8. Januar 2009 auf seiner 6063 .
# 1      Sitzung als Reaktion auf den sogenannten Gaza-Krieg bei einer Enthaltung durch die Vereinigten Staaten einstimmig verabschiedet hat .
# 2      In der Resolution wurden die Konfliktparteien Israel und die palästinensische radikal-islamistische Hamas zu einer sofortigen Waffenruhe aufgefordert .
# 27     Um das Jahr 1000 v. Chr. war Sizilien hauptsächlich von drei Völkern besiedelt , den Sikanern , den Sikulern und den Elymern .
# 28     Es folgte ab etwa 800 v. Chr. eine Periode der Kolonialisierung durch Phöniker , Griechen und Karthager beziehungsweise Punier , die ihre Siedlungen vornehmlich an der Küste errichteten .
# 29     In dieser Zeit war Sizilien als Teil Großgriechenlands vor allem von der Kultur griechischer Siedler geprägt .
# 30     Die bedeutendste griechische Stadt Siziliens war Syrakus .
# 31     Die Blütezeit der griechischen Kultur war das 5. Jahrhundert v. Chr. , nachdem die Griechen im Jahr 480 v. Chr. in der Schlacht bei Himera die Karthager besiegt hatten .
# 32     In diese Zeit fiel die Errichtung der meisten griechischen Tempel Siziliens .
# 33     Nachdem die damalige Großstadt Karthago den wachsenden Bedarf an Korn für sich und das Söldnerheer nicht mehr hatte decken können und das Korn ohne Zwischenhandel beschaffen wollte , landeten die Punier auf der Nordseite der Insel .
# ...
# 161    no_status
# 162    no_status
# 163    no_status
# 164    no_status
# 165    no_status
# 166    no_status
# 167    no_status
# 168    no_status
# 169    no_status
# 170    no_status
# 171    no_status
# 172    no_status
# 173    no_status
# 174    no_status
# 175    no_status
# 176    no_status
# 177    no_status
# 178    no_status
# 179    no_status
# 180    no_status
# 181    no_status
# 182    no_status
# 183    no_status
# 184    no_status
# 185    no_status
# 186    no_status
# 187    no_status
# 188    no_status
# 189    no_status
# 190    no_status
# 191    no_status
# 192    no_status
# 193    no_status
# 194    no_status
# 195    no_status
# 196    no_status
# 197    no_status
# 198    no_status
# 199    no_status
# 200    no_status
# 201    no_status
# 202    no_status
# 203    no_status
# 204    no_status
# 205    no_status
# 206    no_status
# 207    no_status
# 208    no_status
# 209    no_status
# 210    no_status
# 211    no_status
# 212    no_status
# 213    no_status
# 214    no_status
# 215    no_status
# 216    no_status
# 217    no_status
# 218    no_status
# 219    no_status
# 220    no_status
# 221    no_status
# 222    no_status
# 223    no_status
# 224    no_status
# 225    no_status
# 226    no_status
# 227    no_status
# 228    no_status
# 229    no_status
# 230    no_status
# 231    no_status
# 232    no_status
# 233    no_status
# 234    no_status
# 235    no_status
# 236    no_status
# 237    no_status
# 238    no_status
# 239    no_status
# 240    no_status
# 241    no_status
# 242    no_status
# 243    no_status
# 244    no_status
# 245    no_status
# 246    no_status
# 247    no_status
# 248    no_status
# 249    no_status
# 250    no_status
# 251    no_status
# 252    no_status
# 253    no_status
# 254    no_status
# 255    no_status
# 256    no_status
# 257    no_status
# 258    no_status
# 259    no_status
# 260    no_status
# 261    no_status
# 262    no_status
# 263    no_status
# 264    no_status
# 265    no_status
# 266    no_status
# 267    no_status
# 268    no_status
# 269    no_status
# 270    no_status
# 271    no_status
# 272    no_status
# 273    no_status
# 274    no_status
# 275    no_status
# 276    no_status
# 277    no_status
# 278    no_status
# 279    no_status
# 280    no_status
# 281    no_status
# 282    no_status
# 283    no_status
# 284    no_status
# 285    no_status
# 286    no_status
# 287    no_status
# 288    no_status
# 289    no_status
# 290    no_status
# 291    no_status
# 292    no_status
# 293    no_status
# 294    no_status
# 295    no_status
# 296    no_status
# 297    no_status
# 298    no_status
# 299    no_status
# 300    no_status
# 301    no_status
# 302    no_status
# 303    no_status
# 304    no_status
# 305    no_status
# 306    no_status
# 307    no_status
# 308    no_status
# 309    no_status
# 310    no_status
# 311    no_status
# 312    no_status
# 313    no_status
# 314    no_status
# 315    no_status
# 316    no_status
# 317    no_status
# 318    no_status
# 319    no_status
# 320    no_status
# 321    no_status
# 322    no_status
# 323    no_status
# 324    no_status
# 325    no_status
# 326    no_status
# 327    no_status
# 328    no_status
# 329    no_status
# 330    no_status
# 331    no_status
# 332    no_status
# 333    no_status
# 334    no_status
# 335    no_status
# 336    no_status
# 337    no_status
# 338    no_status
# 339    no_status
# 340    no_status
# 341    no_status
# 342    no_status
# 343    no_status
# 344    no_status
# 345    no_status
# 346    no_status
# 347    no_status
# 348    no_status
# 349    no_status
# 350    no_status
# 351    no_status
# 352    no_status
# 353    no_status
# 354    no_status
# 355    no_status
# 356    no_status
# 357    no_status
# 358    no_status
# 359    no_status
# 360    no_status
# 361    no_status
# 362    no_status
# 363    no_status
# 364    no_status
# 365    no_status
# 366    no_status
# 367    no_status
# 368    no_status
# 369    no_status
# 370    no_status
# 371    no_status
# 372    no_status
# 373    no_status
# 374    no_status
# 375    no_status
# 376    no_status
# 377    no_status
# 378    no_status
# 379    no_status
# 380    no_status
# 381    no_status
# 382    no_status
# 383    no_status
# 384    no_status
# 385    no_status
# 386    no_status
# 387    no_status
# 388    no_status
# 389    no_status
# 390    no_status
# 391    no_status
# 392    no_status
# 393    no_status
# 394    no_status
# 395    no_status
# 396    no_status
# 397    no_status
# 398    no_status
# 399    no_status
# 400    no_status
# 401    no_status
# 402    no_status
# 403    no_status
# 404    no_status
# 405    no_status
# 406    no_status
# 407    no_status
# 408    no_status
# 409    no_status
# 410    no_status
# 411    no_status
# 412    no_status
# 413    no_status
# 414    no_status
# 415    no_status
# 416    no_status
# 417    no_status
# 418    no_status
# 419    no_status
# 420    no_status
# 421    no_status
# 422    no_status
# 423    no_status
# 424    no_status
# 425    no_status
# 426    no_status
# 427    no_status
# 428    no_status
# 429    no_status
# 430    no_status
# 431    no_status
# 432    no_status
# 433    no_status
# 434    no_status
# 435    no_status
# 436    no_status
# 437    no_status
# 438    no_status
# 439    no_status
# 440    no_status
# 441    no_status
# 442    no_status
# 443    no_status
# 444    no_status
# 445    no_status
# 446    no_status
# 447    no_status
# 448    no_status
# 449    no_status
# 450    no_status
# 451    no_status
# 452    no_status
# 453    no_status
# 454    no_status
# 455    no_status
# 456    no_status
# 457    no_status
# 458    no_status
# 459    no_status
# 460    no_status
# 461    no_status
# 462    no_status
# 463    no_status
# 464    no_status
# 465    no_status
# 466    no_status
# 467    no_status
# 468    no_status
# 469    no_status
# 470    no_status
# 471    no_status
# 472    no_status
# 473    no_status
# 474    no_status
# 475    no_status
# 476    no_status
# 477    no_status
# 478    no_status
# 479    no_status
# 480    no_status
# 481    no_status
# 482    no_status
# 483    no_status
# 484    no_status
# 485    no_status
# 486    no_status
# 487    no_status
# 488    no_status
# 489    no_status
# 490    no_status
# 491    no_status
# 492    no_status
# 493    no_status
# 494    no_status
# 495    no_status
# 496    no_status
# 497    no_status
# 498    no_status
# 499    no_status
# ...          ...
# 46370  no_status
# 46371  no_status
# 46372  no_status
# 46373  no_status
# 46374  no_status
# 46375  no_status
# 46376  no_status
# 46377  no_status
# 46378  no_status
# 46379  no_status
# 46380  no_status
# 46381  no_status
# 46382  no_status
# 46383  no_status
# 46384  no_status
# 46385  no_status
# 46386  no_status
# 46387  no_status
# 46388  no_status
# 46389  no_status
# 46390  no_status
# 46391  no_status
# 46392  no_status
# 46393  no_status
# 46394  no_status
# 46395  no_status
# 46396  no_status
# 46397  no_status
# 46398  no_status
# 46399  no_status
# 46400  no_status
# 46401  no_status
# 46402  no_status
# 46403  no_status
# 46404  no_status
# 46405  no_status
# 46406  no_status
# 46407  no_status
# 46408  no_status
# 46409  no_status
# 46410  no_status
# 46411  no_status
# 46412  no_status
# 46413  no_status
# 46414  no_status
# 46415  no_status
# 46416  no_status
# 46417  no_status
# 46418  no_status
# 46419  no_status
# 46420  no_status
# 46421  no_status
# 46422  no_status
# 46423  no_status
# 46424  no_status
# 46425  no_status
# 46426  no_status
# 46427  no_status
# 46428  no_status
# 46429  no_status
# 46430  no_status
# 46431  no_status
# 46432  no_status
# 46433  no_status
# 46434  no_status
# 46435  no_status
# 46436  no_status
# 46437  no_status
# 46438  no_status
# 46439  no_status
# 46440  no_status
# 46441  no_status
# 46442  no_status
# 46443  no_status
# 46444  no_status
# 46445  no_status
# 46446  no_status
# 46447  no_status
# 46448  no_status
# 46449  no_status
# 46450  no_status
# 46451  no_status
# 46452  no_status
# 46453  no_status
# 46454  no_status
# 46455  no_status
# 46456  no_status
# 46457  no_status
# 46458  no_status
# 46459  no_status
# 46460  no_status
# 46461  no_status
# 46462  no_status
# 46463  no_status
# 46464  no_status
# 46465  no_status
# 46466  no_status
# 46467  no_status
# 46468  no_status
# 46469  no_status
# 46470  no_status
# 46471  no_status
# 46472  no_status
# 46473  no_status
# 46474  no_status
# 46475  no_status
# 46476  no_status
# 46477  no_status
# 46478  no_status
# 46479  no_status
# 46480  no_status
# 46481  no_status
# 46482  no_status
# 46483  no_status
# 46484  no_status
# 46485  no_status
# 46486  no_status
# 46487  no_status
# 46488  no_status
# 46489  no_status
# 46490  no_status
# 46491  no_status
# 46492  no_status
# 46493  no_status
# 46494  no_status
# 46495  no_status
# 46496  no_status
# 46497  no_status
# 46498  no_status
# 46499  no_status
# 46500  no_status
# 46501  no_status
# 46502  no_status
# 46503  no_status
# 46504  no_status
# 46505  no_status
# 46506  no_status
# 46507  no_status
# 46508  no_status
# 46509  no_status
# 46510  no_status
# 46511  no_status
# 46512  no_status
# 46513  no_status
# 46514  no_status
# 46515  no_status
# 46516  no_status
#
# [46517 rows x 6 columns]

# %%
import hashlib

SAMPLE_RATE = 16000
for sen in s:
    m = hashlib.sha256()
    m.update(sen[0].encode())
    out_filename = path.join(basepath, m.hexdigest() + ".wav")
    in_filename = path.join(basepath, "audio.ogg")
    
    transformer = Transformer()
    transformer.trim(sen[1]/1000.0, sen[2]/1000.0)
    transformer.convert(samplerate=SAMPLE_RATE)
    transformer.build(in_filename, out_filename)
    
    print(out_filename.split("/")[-1], sen, sen[1]/1000.0, sen[2]/1000.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-e599f9cc9a29> in <module>
#       9
#      10     transformer = Transformer()
# ---> 11     transformer.trim(sen[1]/1000.0, sen[2]/1000.0)
#      12     transformer.convert(samplerate=SAMPLE_RATE)
#      13     transformer.build(in_filename, out_filename)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'

# %%
dff["sentence"]
# Out:
# 0     Sitzung als Reaktion auf den sogenannten Gaza-Krieg bei einer Enthaltung durch die Vereinigten Staaten einstimmig verabschiedet hat
# 1     Dauerhafte und geregelte Öffnung der Grenzübergänge für Menschen und Güter
# 2     Der Sicherheitsrat begrüßt sowohl den ägyptischen Vorstoß einen Waffenstillstand zuwege zu bringen als auch andere derzeit laufende regionale und internationale Initiativen
# 0     Die Küstenlänge beträgt 1152 Kilometer
# 1     Nur selten war die Insel politisch selbständig zumeist wurde sie von Reichen oder Staaten beherrscht die ihr politisches Zentrum anderswo hatten
# 2     In dieser Zeit war Sizilien als Teil Großgriechenlands vor allem von der Kultur griechischer Siedler geprägt
# 3     Die bedeutendste griechische Stadt Siziliens war Syrakus
# 4     405 v. Chr. wurde Syrakus besetzt
# 5     Dionysios konnte die Karthager abwehren
# 6     Sizilien wurde der wichtigste Getreidelieferant Roms
# 7     Unter den Arabern wurde Palermo zur bedeutendsten Stadt Siziliens
# 8     Aragon Spanien Savoyen und Österreich folgten aufeinander
# 9     Diese genoss anfangs zwar einige Zustimmung konnte sich letztendlich jedoch nicht durchsetzen
# 10    Unruhen und Aufstände wurden niedergeschlagen und so wanderten zwischen 1880 und dem Beginn des ersten Weltkriegs viele Sizilianer vorwiegend nach Amerika aus
# 11    Seit der Landflucht nach dem Zweiten Weltkrieg sind vor allem die Küstengebiete dicht besiedelt
# 12    Eine weitere Gruppe bilden Muslime aus Nordafrika vor allem aus Tunesien
# 13    Sitz des sizilianischen Parlaments und der Regierung ist die Hauptstadt Palermo
# 14    Weitere Provinzen sind Agrigent Caltanissetta Enna Messina Ragusa Syrakus und Trapani
# 15    Wie andere Teile Süditaliens leidet Sizilien unter der organisierten Kriminalität durch die Mafia
# 16    Haupterwerbsquelle der Sizilianer ist der Dienstleistungssektor knapp 70 % der Arbeitsplätze fallen in diesen Bereich
# 17    Hierzu trägt der wachsende Tourismus bei
# 18    Angaben 2005
# 19
# 20    Schwerpunkt sind petrochemische Industriebetriebe der Maschinen und der Schiffbau
# 21
# 22    Die Universität Catania ist die älteste und größte
# 23    Umweltschäden sind auf Sizilien nicht zu übersehen
# 0     Als sie acht Jahre alt ist erzählt ihr ihr älterer Bruder die Sage von Ikarus
# 1     Das Kind ist fasziniert von der Geschichte und von der Idee des Fliegens
# 2     Beate ist ein wildes Kind
# 0     Nach Vorgabe soll eventuell verbliebener amorpher Kohlenstoff der Kremierungsasche zu einem synthetischen Diamanten veredelt werden
# 1     Veraschen ist eine thermische Zersetzung aller organischen Verbindungen
# 2
# 3     Zur Gewinnung von Diamanten werden die natürlichen Entstehungsbedingungen von Diamantkristallen nachgebildet
# 4
# 5     Bei Bestattungsdiamanten ist ein bläulicher Schimmer durch Boreinschlüsse typisch
# 6     Andere Färbungen sind durch wesensfremde Ausgangsstoffe bedingt
# 7     In Österreich gibt es inzwischen Möglichkeiten
# 8     Bestattungszwang
# 9     Damit sind die sterblichen Reste auch die Kremationsasche auf vorgeschriebenen und für diesen Zweck freigegebenen Flächen aufzubewahren
# 10    Es verbleibt eine Substanzmenge die gesetzeskonform beigesetzt werden kann
# 0     Die Designkriterien der Sprache sind
# 1     Jedes Ook
# 2     Zeilenumbrüche werden ignoriert
# 3     Programme
# 0     Aktueller Vorsitzender ist Herbert Neuhaus
# 0     Bevorzugt werden Mayas die Opfer des Bürgerkriegs sind
# 0     Die Ausbildungsdauer beträgt drei Jahre
# 1     Ihre Tätigkeit ist von Logistik Verfahrenstechnik Qualitätssicherung Entsorgung und technischem Support geprägt
# 2     Fachrichtungen
# 3     Halbleitertechnik Mikrosystemtechnik
# 4     Typische Einsatzgebiete sind zum Beispiel die Herstellung von Schaltungsträgern in Dickschichttechnik oder Dünnschichttechnik Hybridtechnik SMD-Montagetechnik Herstellung von Bauelementen durch lithografisches Tiefätzen oder Galvano und Abformtechnik
# 0     Capito galt als korrupt
# 1     Bis dahin blieb der Posten vakant
# 0     Lessing verarbeitete in diesem Drama den Stoff der Legende um die Römerin Verginia den er an zentralen Stellen veränderte
# 1     Emilia Galotti ist ein Drama der Aufklärung das nicht dem damals vorherrschenden französischen Vorbild entspricht und sich darüber hinaus auch von Johann Christoph Gottscheds Regelpoetik absetzt
# 2     Emilia wird auf das in der Nähe gelegene Lustschloss des Prinzen in scheinbare Sicherheit gebracht erkennt jedoch im Gegensatz zu ihrer Mutter Claudia die wahren Zusammenhänge der Intrige nicht
# 3     Doch Odoardo zögert den Prinzen zu erstechen und will zunächst Gott die Rache überlassen
# 4     Der Tochtermörder sieht jedoch Gott als letzte Instanz an
# 5     Lessing beschreibt den Konflikt zwischen Adel und Bürgertum
# 6     Lessing verdeutlicht an der Figur Odoardo wie sehr sich das Bürgertum des 18. Jahrhunderts im Umbruch befand
# 7     Odoardo zeigt zwar schon Ansätze eines neuen rationalen Denkens
# 0     Bei schwarzem Hauttyp sind die Melanosomen zahlreicher größer einzeln und über diese Hautzelle verteilt
# 1     Immunhistochemisch sind Melanozyten S-100-positiv
# 2     Melanozyten sind also Abkömmlinge des Neuroektoderms
# 3     Außer den kutanen in Epidermis und Haarfollikeln werden später Melanozytenpopulationen auch in der Uvea des Auges in der Stria vascularis des Innenohrs
# 4     gefunden
# 5     Die Bildung von Melanin Eu und Pheomelanin die so genannte Melanogenese beginnt mit der Synthese des zunächst inaktiven Enzyms Tyrosinase
# 6     Dieses wird in das raue endoplasmatische Retikulum synthetisiert und sammelt sich im Golgi-Apparat an der sie dann in Vesikel abschnürt
# 7     Hierbei spielt auch das Protein Trp-1 eine Rolle
# 8     In niederen Vertebraten Fische Amphibien verbleiben die Melanosomen intrazellulär und werden nicht abgegeben
# 9     Bei folgenden Erkrankungen spielen Melanozyten beziehungsweise Melanozyten-Vorläufer eine wichtige Rolle
# 10    Vitiligo Melanome Hautmelanom Aderhautmelanom Bindehautmelanom Dysplastischer Nävus Lentigo Hyperpigmentierung Nävuszellnävus Albinismus Leuzismus Scheckung
# 0     Die Klassifizierung als Virus bezieht sich hierbei auf die Verbreitungs und Infektionsfunktion
# 1     Einmal gestartet kann es vom Anwender nicht kontrollierbare Veränderungen am Status der Hardware am Betriebssystem oder an der Software vornehmen Schadfunktion
# 2     Wie sein biologisches Vorbild benutzt ein Computervirus die Ressourcen seines Wirtcomputers und schadet ihm dabei häufig
# 3     Auch vermehrt es sich meist unkontrolliert
# 4     Heutzutage sind Computerviren fast vollständig von Würmern verdrängt worden da fast jeder Rechner an das Internet oder lokale Netze angeschlossen ist und die aktive Verbreitungsstrategie der Würmer in kürzerer Zeit eine größere Verbreitung ermöglicht
# 5     In freier Wildbahn werden allerdings weitaus weniger verschiedene Viren beobachtet als theoretisch bekannt sind
# 6     Der wirtschaftliche Schaden durch Computerviren ist geringer als der Schaden durch Computerwürmer
# 7     Ein Beispiel ist das Virus DataCrime das gesamte Datenbestände vernichtet hat
# 8     Auch unter Windows gab es vereinzelt Fälle von Computer-Viren die gravierende finanzielle Schäden für einzelne Unternehmen bedeuteten
# 9     Manche Viren können mehr Funktionen haben andere wiederum weniger
# 10    Entschlüsselungsroutine Dieser Teil sorgt bei verschlüsselten Viren dafür dass die verschlüsselten Daten wieder zur Ausführung gebracht werden können
# 11    Nicht alle Viren besitzen diesen Teil da nicht alle verschlüsselt sind
# 12    Vermehrungsteil Dieser Programmteil sorgt für die Vermehrung des Virus
# 13    Es ist der einzige Teil den jedes Virus hat Definition
# 14    Dieser Teil ist in fast allen nicht-überschreibenden Computerviren vorhanden
# 15    Tarnungsteil Ein Tarnungsteil ist nur in wenigen komplexen Viren vorhanden
# 16    Er kann das Virus zum Beispiel verschlüsseln oder ihm eine andere Form geben Polymorphismus Metamorphismus
# 17    Dieser Teil dient zum Schutz des Virus vor der Erkennung durch Anti-Viren-Software
# 0     Nur in der Dekadenzdichtung hat das Wort auch eine positive Bedeutung im heutigen Sprachgebrauch überwiegt der abwertende Charakter
# 1     die sich mit dem Untergang des Römischen Reiches beschäftigten
# 2     Als Gründe werden u.a. Abkehr vom wahren Glauben oder eine Verfälschung des göttlichen Willens angenommen der westliche Kapitalismus wird abgelehnt da er Dekadenz Armut und Unglaube verursache
# 3     Statt wirtschaftlicher und kultureller Reformen wird die Rückkehr zu den Grundlagen des Islam gefordert
# 4     Auch aktuell sprechen unterschiedliche dem radikalen Spektrum zugeordnete Gruppen und Parteien von Dekadenz
# 5
# 0     Der Vorteil des Selbstfahrerbetriebs ist die mögliche größere Spontanität und Kreativität des Moderators außerdem wird der Ton / Sendetechniker eingespart
# 0     Schon kurz nach Gründung des Vereins taten sich meteorologisch interessierte Mitglieder zusammen und führten Wetterbeobachtungen durch
# 1     Als im Jahr 1914 die Frankfurter Universität gegründet wurde brachte der Physikalische Verein acht seiner naturwissenschaftlichen Institute in die Stiftung ein
# 2     Insgesamt vergibt der Physikalische Verein jedes Jahr vier Stiftungspreise zwei davon werden an Jugendliche verliehen die in der Amateurforschung auf dem Gebiet der Astronomie oder Umwelttechnik besondere Leistungen erbracht haben
# 3     Mittwochs findet das Vorstellungsprogramm Aus Naturwissenschaft und Technik statt in dem Wissenschaftler und Ingenieure ihre Forschungsergebnisse und Entwicklungen präsentieren
# 0     Der Spindlerbrunnen ist eine Brunnenanlage auf dem Spittelmarkt in Berlin-Mitte
# 1     Das Material ist schwedischer roséfarbener Granit
# 2     Das Brunnenbecken hat einen Durchmesser von 10 Meter
# 3     Die untere Schale wiegt 12 Tonnen die obere 7 Tonnen
# 0     Sie ist in Deutschland streng geschützt rote Liste und darf weder gefangen noch gehalten werden
# 1     Während die beiden hinteren Beinpaare als Schreitbeine gestaltet sind sind die Vorderbeine zu Fangbeinen umgebildet
# 2     Femur und Tibia sind mit Dornen zum Festhalten der Beute besetzt
# 3     Erst 14 Tage nach der Imaginalhäutung werden die Tiere geschlechtsreif
# 4     Einzelne Fundmeldungen gibt es auch aus Hessen und dem Saarland
# 0     Die Hülle dient als mechanische Führung des Zugs und als Gegenlager für die übertragenen Zugkräfte so dass der Bowdenzug Kräfte auch über mehrfach gebogene Pfade übertragen kann
# 1     In der Feinwerktechnik werden Bowdenzüge vielfältig eingesetz zum Beispiel als Auslösemechanismen in der professionellen Fotografie
# 0     Regie führte Michael Bay in den Hauptrollen sind Ewan McGregor und Scarlett Johansson zu sehen
# 1     Der Film basiert auf dem Roman Spares dt. Titel Geklont von Michael Marshall Smith
# 2     Doch diese sterile Welt ist nur eine Illusion
# 3     Tatsächlich ist die Lotterieziehung jedoch fingiert sodass immer genau diejenigen Klone die scheinbare Reise antreten dürfen deren Organe gerade von ihrem Original dem sogenannten Sponsor in der wirklichen Welt gebraucht werden
# 4     Dadurch wird den Klonen der Weggang ihrer Mitbewohner plausibel gemacht
# 5     Lincoln trifft sogar sein wahres Ich den Designer Tom Lincoln
# 6     Allerdings hintergeht Tom Lincoln seinen Klon da er in naher Zukunft dessen Leber benötigt
# 7     Lincoln Six Echo schlüpft in die Rolle des echten Tom Lincoln wodurch dieser erschossen wird
# 8     Durch die Einführung von massenhaften Lotteriegewinnen sollen sie gruppenweise in eine als Gaskammer genutzte Brennkammer gebracht und getötet werden
# 9     Dr. Merrick wird beim Versuch dies zu verhindern im Kampf mit Lincoln getötet
# 10    Ursprünglich sollte der Film zum Ende des 21. Jahrhunderts spielen
# 11    Teile des Films wurden in der Geisterstadt Rhyolite Nevada in der Los Angeles Union Station sowie in dem verfallenden alten Hauptbahnhof in Detroit gedreht
# 12    Kilb moniert weiter
# 13    So wird unübersehbar für mehrere große Sport und Kommunikationskonzerne geworben
# 14    Sie forderten sowohl Schadensersatz als auch Gewinnbeteiligung
# ...
# 4     Mit herkömmlichem Mais der hauptsächlich zur Gewinnung von Stärke oder Viehfutter angebaut wird ist es nur sehr schlecht oder gar nicht möglich Popcorn herzustellen
# 5     Normale Maiskörner sind entweder zu trocken oder zu weich wodurch das im Inneren gebundene erhitzte Wasser nur wenig Druck aufbauen kann
# 6     Bei Beschädigungen kann das Wasser auch direkt durch Öffnungen entweichen
# 7     Für Kleinkinder gibt es auch Spielzeuge aus Plastik wobei nur Teile davon mit Popcorn gefüllt sind dieses Popcorn ist meistens mit Lebensmittelfarbe bunt gefärbt und viel feiner gekörnt
# 0     und findet heute weltweit Anwendung
# 1     So wurde 1868 die erste Fußgängerfurt ampelreguliert
# 2     Angestrebt wurde ein optimales Verkehrsnetz mit Hauptstraßen für den Schnellverkehr und Nebenstraßen für Zubringer und Langsamverkehr
# 3     Eine Unterordnung schwächerer nichtmotorisierter Verkehrsteilnehmer sollte durch Maßnahmen wie Fußgängerüberwege oder Absperrungen verdeutlicht werden
# 4     Mit dem Städtetag 1960 wurde das Leitbild der Segregation endgültig zum Paradigma der Begriff der Autogerechten Stadt
# 5     kam auf
# 6     Zudem entstand im Zuge der Urbanisierung eine neue Qualität des Pendlerverhaltens was die Verkehrswege weiter belastete
# 7     In dieser Zeit war erstmals das Konzept verkehrsberuhigter Bereiche im Gespräch
# 0     500 Rubel wurden gegen 1 Tenge eingetauscht
# 1     Auf Kasachisch bedeutet Tenge so viel wie Gleichgewicht
# 0     Er stellt eine divergierende Plattengrenze dar
# 0     Nagoya ist mit 2,3 Mio Einwohnern nach Tokio Yokohama und Ōsaka viertgrößtes japanisches Industriezentrum und sportlich hauptsächlich durch den Baseballverein Chūnichi Dragons und den Fußballverein Nagoya Grampus Eight bekannt
# 1     1610 wurde die Burg von Nagoya von Tokugawa Ieyasu wieder aufgebaut
# 2     Anschließend wurde Nagoya wieder zum eindeutigen Zentrum Owaris
# 3     Bürgermeister von Nagoya ist seit April 2009 der ehemalige demokratische Abgeordnete Takashi Kawamura der bei einer vorzeitigen Neuwahl im Februar 2011 im Amt bestätigt wurde
# 4     Der zentrale Eisenbahnknotenpunkt ist der Bahnhof Nagoya mit den JR Central Towers er gilt als höchstes Bahnhofsgebäude der Welt
# 5     In Nagoya befinden sich die Universität Nagoya und die Städtische Universität Nagoya
# 6     Fußball
# 7     Baseball
# 8     Nagoya-Marathon
# 0     Dieses unterscheidet Mikrofone von Tonabnehmern die Festkörperschwingungen umsetzen
# 1     Unterwasser-Mikrofone werden als Hydrofone bezeichnet
# 2
# 3     Eine Ausnahme sind Infraschall-Sensoren
# 4     Den Einsatz von Mikrofonen bezeichnet man als Mikrofonierung
# 5     Dabei wird je nach Anwendung nach technischen klanglichen und wirtschaftlichen Gesichtspunkten optimiert
# 0     Folglich wurde der Stadtname Shingishū 新義州 gelesen
# 1     Sein festliches Design ist bemerkenswert
# 2     Der fünffache nordkoreanische Fußball-Meister Lokomotive Sinŭiju trägt seine Heimspiele im Sinŭiju-Stadion aus
# 0     Wilhelm Trute kam 1836 in Sankt Andreasberg als einziges Kind von Georg Conrad Trute und Johanna Henriette Trute geb. Keitel zur Welt
# 1     Es ist anzunehmen dass aus dieser Kreuzung die ersten Harzer Roller hervorgingen
# 2     Auch hat er die Tiere nur ungern per Versandhandel verkauft
# 3     Händler und Endabnehmer mussten diese in Andreasberg beim Züchter selbst abholen
# 0     Sie erreichen eine Höchstgeschwindigkeit von 60 Kilometern pro Stunde
# 1     Für den Fahrgast ist vor allem die modifizierte Stirnfront auffällig der Innenraum blieb unverändert
# 2     Bei den Linien M2 und M3 erfolgt lediglich die Ansage
# 3     Freie Flächen für den Bau einer Werkstatt fanden sich am Bahnhof Kőbánya-Kispest
# 0     Dörenhagen ist der östlichste der fünf Ortsteile der Gemeinde Borchen im Kreis Paderborn Nordrhein-Westfalen
# Name: sentence, Length: 8350, dtype: object
